# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy import linspace
from scipy.stats import binom
from scipy.stats import poisson

# %%
def poissonpmf(lambdaa, k):
    return (lambdaa ** k / math.factorial(k)) * math.e ** (-lambdaa)

# %%
outcome_counts = linspace(0, 10 , 11)
probabilidades = []
lamb = 1
for i in outcome_counts:
    probabilidades.append(poissonpmf(lamb, i))
    
plt.bar(outcome_counts,probabilidades)
plt.show()

# %%
outcome_counts = linspace(0, 10 , 11)
probabilidades = []
lamb = 4
for i in outcome_counts:
    probabilidades.append(poissonpmf(lamb, i))
    
plt.bar(outcome_counts,probabilidades)
plt.show()

# %%
outcome_counts = linspace(0, 10 , 11)
probabilidades = []
lamb = 10
for i in outcome_counts:
    probabilidades.append(poissonpmf(lamb, i))
    
plt.bar(outcome_counts,probabilidades)
plt.show()

# %%
def poissoncdf(linspace,lambdaa) :
    probabilidades = []
    for i in linspace:
        probabilidades.append(poisson.cdf(i,lambdaa))
    return probabilidades

# %%
temp = poissoncdf(outcome_counts,1)
plt.bar(outcome_counts, temp)
plt.show()

# %%
temp = poissoncdf(outcome_counts,4)
plt.bar(outcome_counts, temp)
plt.show()

# %%
temp = poissoncdf(outcome_counts,10)
plt.bar(outcome_counts, temp)
plt.show()
